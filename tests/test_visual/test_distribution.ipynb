# %% [markdown]
# # Distribution Plot Visualation Unit Tests

# %%
import pandas as pd
from explorer.visual.distribution import Histogram, KDEPlot, BoxPlot, ViolinPlot, ECDFPlot

# %%
from explorer.container import ExplorerContainer
container = ExplorerContainer()
container.init_resources()

# %% [markdown]
# ## Data

# %%
FP = "data/Credit Score Classification Dataset.csv"
df = pd.read_csv(FP, index_col=None)

# %%
df.head()
# Out:
#    Age  Gender  Income            Education Marital Status  Children     Own  \
# 0   25  Female   50000    Bachelor's Degree         Single         0  Rented
# 1   30    Male  100000      Master's Degree        Married         2   Owned
# 2   35  Female   75000            Doctorate        Married         1   Owned
# 3   40    Male  125000  High School Diploma         Single         0   Owned
# 4   45  Female  100000    Bachelor's Degree        Married         3   Owned
#
#   Credit Rating
# 0          High
# 1          High
# 2          High
# 3          High
# 4          High

# %% [markdown]
# ## Histogram

# %%
hist = Histogram()
hist(data=df,x="Age",hue='Gender', title="Test Histogram", stat="count", multiple='dodge')

# %% [markdown]
# ## KDEPlot

# %%
plot = KDEPlot()
plot(data=df,x="Income",hue='Gender', title="Test KDEPlot")

# %% [markdown]
# ## Boxplot

# %%
plot = BoxPlot()
plot(data=df,x="Income",y='Gender', title="Test Box Plot")

# %% [markdown]
# ## Violin Plot

# %%
plot = ViolinPlot()
plot(data=df,x="Income",y='Gender',  title="Test Violin Plot")

# %% [markdown]
# ## ECDF Plot

# %%
plot = ECDFPlot()
plot(data=df,x="Income",hue='Gender',  title="Test ECDF Plot")
