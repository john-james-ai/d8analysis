# %% [markdown]
# # Probability Density Functions

# %%
from d8analysis.service.io import IOService
from d8analysis.visual.rv_continuous import TTestPlot
from d8analysis.quantitative.statistical.centrality.ttest import TTestResult
from d8analysis.container import d8analysisContainer

# %%
container = d8analysisContainer()
container.init_resources()

# %%
result = TTestResult(
    result= f"Independent Samples t Test\nX: (N = 78, M = 40.06, SD = 8.16)\nY: (N = 86, M = 36.08, SD = 8.26)\nt(162) = 3.08, P=0.002 significant at 5%.",
    dof=162,
    value=3.0837738032031523,
    pvalue=0.002406278366806392,
    alpha=0.05,
)
p = TTestPlot(result=result)
p.plot()
