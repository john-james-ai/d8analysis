# %% [markdown]
# # T-Test

# %%
from d8analysis.quantitative.inferential.centrality.ttest import TTest
from d8analysis.service.io import IOService
from scipy import stats

# %%
from d8analysis.container import D8AnalysisContainer
container = D8AnalysisContainer()
container.init_resources()
container.wire(packages=["d8analysis.quantitative.inferential", "d8analysis.visual.seaborn"])

# %%
FP = "data/Credit Score Classification Dataset.csv"
STATISTICS = ['ks', 'ad', 'cvm']

# %%
df = IOService.read(FP, index_col=None)
female = df.loc[df['Gender'] == 'Female']['Age']
male = df.loc[df['Gender'] == 'Male']['Age']

# %%
test = TTest(a=female, b=male)
test.run()
print(test.result)
test.result.plot()
# Out:
#                           TTestResult
#                             Test | T-test - Independent Samples
#                       Hypothesis | Centrality
#                               H0 | The means of two independent samples, drawn from a normal distribution, with equal variances, are identical.
#                        Statistic | T
#                            Value | 3.0837738032031523
#                           Pvalue | 0.002406278366806392
#                        Inference | The pvalue 0.0 is less than level of significance 5%; therefore, the null hypothesis is rejected. The evidence against identical centers for a and b is significant.
#                            Alpha | 0.05
#                           Result | Independent Samples t Test
# a: (N = 86, M = 36.08, SD = 8.26)
# b: (N = 78, M = 40.06, SD = 8.16)
# t(162) = -3.08, P=0.002 significant at 5%.
#                              Dof | 162
#                    Homoscedastic | False
