# %% [markdown]
# # Spearman Correlation

# %%
# %matplotlib inline
from d8analysis.quantitative.inferential.relational.spearman import SpearmanCorrelationTest
from d8analysis.service.io import IOService
from d8analysis.data.generation import RVSDistribution
import numpy as np
import pandas as pd

import matplotlib

# %%
from d8analysis.container import D8AnalysisContainer
container = D8AnalysisContainer()
container.init_resources()
container.wire(packages=["d8analysis.quantitative.inferential", "d8analysis.visual.seaborn"])

# %%
FP = "data/Credit Score Classification Dataset.csv"
STATISTICS = ['ks', 'ad', 'cvm']

# %%
df = IOService.read(FP, index_col=None)
a = 'Age'
b = "Income"

# %%
rvs = RVSDistribution()
income = rvs(data=df['Income'], distribution='norm', size=1000).rvs.y
age = rvs(data=df['Age'], distribution='norm', size=1000).rvs.y
d = {'Income': income, 'Age': age}
df = pd.DataFrame(data=d)

# %%
test = SpearmanCorrelationTest(data=df, a=a, b=b)
test.run()
print(test.result)
test.result.plot()
# Out:
#                    SpearmanCorrelationResult
#                             Test | Spearman's Correlation Test
#                       Hypothesis | Correlation of Two Variables
#                               H0 | Distributions are uncorrelated
#                        Statistic | Spearman’s rho (S)
#                            Value | -0.03266200466200467
#                           Pvalue | 0.3021439108033511
#                        Inference | The two variables had negligible correlation, r(998)=-0.03, P=0.302.
# However, the pvalue, 0.3 is greater than level of significance 5% indicating that the correlation coefficient is not statistically significant.
#                            Alpha | 0.05
#                           Result | Spearman Correlation Test
# r(998)=-0.033, P=0.302
# Negligible correlation
#                                A | Age
#                                B | Income
#                              Dof | 998
