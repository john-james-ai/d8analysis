# %% [markdown]
# # KS Test

# %%
from d8analysis.quantitative.inferential.distribution.kstest import KSTest
from d8analysis.service.io import IOService
from scipy import stats

# %%
from d8analysis.container import D8AnalysisContainer
container = D8AnalysisContainer()
container.init_resources()
container.wire(packages=["d8analysis.quantitative.inferential", "d8analysis.visual.seaborn"])

# %%
FP = "data/Credit Score Classification Dataset.csv"
STATISTICS = ['ks', 'ad', 'cvm']

# %%
df = IOService.read(FP, index_col=None)
a = df.loc[df['Gender'] == 'Male']['Income'].values
b = df.loc[df['Gender'] == 'Female']['Income'].values

# %%
test = KSTest(a=df['Income'].values, b='norm')
test.run()
print(test.result)
test.result.plot()
# Out:
#                           KSTestResult
#                             Test | Kolmogorov-Smirnov Test
#                       Hypothesis | Goodness of Fit
#                               H0 | Data drawn from the same distribution
#                        Statistic | Kolmogorov–Smirnov
#                            Value | 1.0
#                           Pvalue | 0.0
#                        Inference | The pvalue 0.0 is less than level of significance 5%; therefore, the null hypothesis is rejected. The evidence against the data being drawn from the norm is significant.
#                            Alpha | 0.05
#                           Result | D(164)=1.0, p=0.0
#                                B | norm
#                           A_name | Sample 1
#                           B_name | Sample 2

# %%
x = stats.norm.rvs(size=10000)
test = KSTest(a=x, b='norm')
test.run()
print(test.result)
test.result.plot()
# Out:
#                           KSTestResult
#                             Test | Kolmogorov-Smirnov Test
#                       Hypothesis | Goodness of Fit
#                               H0 | Data drawn from the same distribution
#                        Statistic | Kolmogorov–Smirnov
#                            Value | 0.005457001329155053
#                           Pvalue | 0.9254484635527039
#                        Inference | The pvalue 0.93 is greater than level of significance 5%; therefore, the null hypothesis is not rejected. The evidence against the data being drawn from the norm is not significant.
#                            Alpha | 0.05
#                           Result | D(10000)=0.0055, p=0.925
#                   Interpretation | Note: The Kolmogorov-Smirnov Test on large sample sizes may lead to rejections of the null hypothesis that are statistically significant, yet practically insignificant.
#                                B | norm
#                           A_name | Sample 1
#                           B_name | Sample 2

# %%
x = stats.norm.rvs(size=10000)

test = KSTest(a=x, b='norm')
test.run()
print(test.result)
test.result.plot()
# Out:
#                           KSTestResult
#                             Test | Kolmogorov-Smirnov Test
#                       Hypothesis | Goodness of Fit
#                               H0 | Data drawn from the same distribution
#                        Statistic | Kolmogorov–Smirnov
#                            Value | 0.010702998359629956
#                           Pvalue | 0.20067025404847327
#                        Inference | The pvalue 0.2 is greater than level of significance 5%; therefore, the null hypothesis is not rejected. The evidence against the data being drawn from the norm is not significant.
#                            Alpha | 0.05
#                           Result | D(10000)=0.0107, p=0.201
#                   Interpretation | Note: The Kolmogorov-Smirnov Test on large sample sizes may lead to rejections of the null hypothesis that are statistically significant, yet practically insignificant.
#                                B | norm
#                           A_name | Sample 1
#                           B_name | Sample 2

# %%
test = KSTest(a=a, b=b)
test.run()
print(test.result)
test.result.plot()
# Out:
#                           KSTestResult
#                             Test | Kolmogorov-Smirnov Test
#                       Hypothesis | Goodness of Fit
#                               H0 | Data drawn from the same distribution
#                        Statistic | Kolmogorov–Smirnov
#                            Value | 0.5014907573047108
#                           Pvalue | 6.502925934610737e-10
#                        Inference | The pvalue 0.0 is less than level of significance 5%; therefore, the null hypothesis is rejected. The evidence against the data being drawn from the same distribution is significant.
#                            Alpha | 0.05
#                           Result | D(78)=0.5015, p=0.0
#                           A_name | Sample 1
#                           B_name | Sample 2

# %%
test = KSTest(a=a, b=b)
test.run()
print(test.result)
test.result.plot_statistic()
test.result.plot_cdf()
test.result.plot_pdf()
# Out:
#                           KSTestResult
#                             Test | Kolmogorov-Smirnov Test
#                       Hypothesis | Goodness of Fit
#                               H0 | Data drawn from the same distribution
#                        Statistic | Kolmogorov–Smirnov
#                            Value | 0.5014907573047108
#                           Pvalue | 6.502925934610737e-10
#                        Inference | The pvalue 0.0 is less than level of significance 5%; therefore, the null hypothesis is rejected. The evidence against the data being drawn from the same distribution is significant.
#                            Alpha | 0.05
#                           Result | D(78)=0.5015, p=0.0
#                           A_name | Sample 1
#                           B_name | Sample 2

# %%
test = KSTest(a=a, b=b, a_name="Male Income", b_name="Female Income")
test.run()
print(test.result)
test.result.plot_statistic()
test.result.plot_cdf()
test.result.plot_pdf()
# Out:
#                           KSTestResult
#                             Test | Kolmogorov-Smirnov Test
#                       Hypothesis | Goodness of Fit
#                               H0 | Data drawn from the same distribution
#                        Statistic | Kolmogorov–Smirnov
#                            Value | 0.5014907573047108
#                           Pvalue | 6.502925934610737e-10
#                        Inference | The pvalue 0.0 is less than level of significance 5%; therefore, the null hypothesis is rejected. The evidence against the data being drawn from the same distribution is significant.
#                            Alpha | 0.05
#                           Result | D(78)=0.5015, p=0.0
#                           A_name | Male Income
#                           B_name | Female Income
