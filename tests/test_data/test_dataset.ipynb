# %% [markdown]
# # Dataset

# %%
from d8analysis.data.credit import CreditScoreDataset
from d8analysis.container import D8AnalysisContainer
from d8analysis.service.io import IOService

# %%
container = D8AnalysisContainer()
container.init_resources()
container.wire(packages=["d8analysis"])

# %%
fp = "data/Credit Score Classification Dataset.csv"
df = IOService.read(fp)
ds = CreditScoreDataset(df=df)
ds.plot.lineplot(x='Income', y='Age', hue='Education')
ds.plot.lineplot(x='Income', y='Age')
# Out:
# /home/john/projects/d8analysis/d8analysis/data/plot.py:80: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(

# %%
ds.plot.scatterplot(x='Income', y='Age', hue='Education')
ds.plot.scatterplot(x='Income', y='Age')
# Out:
# /home/john/projects/d8analysis/d8analysis/data/plot.py:126: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(

# %%
ds.plot.histogram(x='Income', y='Age', hue='Education')
ds.plot.histogram(x='Income', y='Age')
ds.plot.histogram(x='Income', title='Histogram of Income')
# Out:
# /home/john/projects/d8analysis/d8analysis/data/plot.py:178: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(
# /home/john/projects/d8analysis/d8analysis/data/plot.py:178: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(

# %%
ds.plot.boxplot(x='Income', y='Education')
ds.plot.boxplot(x='Income', title='Histogram of Income')

# %%
ds.plot.kdeplot(x='Income', y='Age')
ds.plot.kdeplot(x='Income', title='Probability Density of Income')
# Out:
# /home/john/projects/d8analysis/d8analysis/data/plot.py:269: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(
# /home/john/projects/d8analysis/d8analysis/data/plot.py:269: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(

# %%
ds.plot.ecdfplot(x='Income', title='Probability Density of Income')
# Out:
# /home/john/projects/d8analysis/d8analysis/data/plot.py:315: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.ecdfplot(

# %%
ds.plot.barplot(x='Income', y='Education')
ds.plot.barplot(x='Income', title='Probability Density of Income')

# %%
ds.plot.violinplot(x='Income', y='Education')
ds.plot.violinplot(x='Income', title='Probability Density of Income')

# %%
ds.plot.histpdfplot(x='Income', y='Education')
ds.plot.histpdfplot(x='Income', title='Probability Density of Income')

# %%
ds.plot.pdfcdfplot(x='Income', title='Probability Density of Income')

# %%
ds.plot.pairplot(vars=['Income', 'Education'])
ds.plot.pairplot(vars=['Income'], title='Probability Density of Income')
# Out:
# /home/john/anaconda3/envs/d8analysis/lib/python3.10/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /home/john/anaconda3/envs/d8analysis/lib/python3.10/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /home/john/anaconda3/envs/d8analysis/lib/python3.10/site-packages/seaborn/axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /home/john/anaconda3/envs/d8analysis/lib/python3.10/site-packages/seaborn/axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /home/john/anaconda3/envs/d8analysis/lib/python3.10/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)

# %%
ds.plot.jointplot(x='Income', y='Education')
ds.plot.jointplot(x='Income', title='Probability Density of Income')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ds.plot.jointplot(vars=['Income', 'Education'])
#       2 ds.plot.jointplot(vars=['Income'], title='Probability Density of Income')
#
# File ~/projects/d8analysis/d8analysis/data/plot.py:587, in DatasetVisualizer.jointplot(self, x, y, hue, title, *args, **kwargs)
#     565 def jointplot(
#     566     self,
#     567     x: str = None,
#    (...)
#     572     **kwargs,
#     573 ) -> None:
#     574     """Draw a plot of two variables with bivariate and univariate graphs.
#     575
#     576         Args:
#    (...)
#     584
#     585     """
# --> 587     g = sns.jointplot(
#     588         data=self._df,
#     589         x=x,
#     590         y=y,
#     591         hue=hue,
#     592         palette=self._canvas.palette,
#     593         *args,
#     594         **kwargs,
#     595     )
#     596     if title is not None:
#     597         g.fig.suptitle(title)
#
# File ~/anaconda3/envs/d8analysis/lib/python3.10/site-packages/seaborn/axisgrid.py:2255, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2252 if kind.startswith("scatter"):
#    2254     joint_kws.setdefault("color", color)
# -> 2255     grid.plot_joint(scatterplot, **joint_kws)
#    2257     if grid.hue is None:
#    2258         marg_func = histplot
#
# File ~/anaconda3/envs/d8analysis/lib/python3.10/site-packages/seaborn/axisgrid.py:1826, in JointGrid.plot_joint(self, func, **kwargs)
#    1823     self._inject_kwargs(func, kwargs, self._hue_params)
#    1825 if str(func.__module__).startswith("seaborn"):
# -> 1826     func(x=self.x, y=self.y, **kwargs)
#    1827 else:
#    1828     func(self.x, self.y, **kwargs)
#
# File ~/anaconda3/envs/d8analysis/lib/python3.10/site-packages/seaborn/relational.py:761, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     758 color = kwargs.pop("color", None)
#     759 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 761 p.plot(ax, kwargs)
#     763 return ax
#
# File ~/anaconda3/envs/d8analysis/lib/python3.10/site-packages/seaborn/relational.py:573, in _ScatterPlotter.plot(self, ax, kws)
#     570     kws.setdefault("edgecolor", "w")
#     572 # Draw the scatter plot
# --> 573 points = ax.scatter(x=x, y=y, **kws)
#     575 # Apply the mapping from semantic variables to artist attributes
#     577 if "hue" in self.variables:
#
# File ~/anaconda3/envs/d8analysis/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/d8analysis/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4698, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4694         keys_str = ", ".join(f"'{k}'" for k in extra_keys)
#    4695         _api.warn_external(
#    4696             "No data for colormapping provided via 'c'. "
#    4697             f"Parameters {keys_str} will be ignored")
# -> 4698 collection._internal_update(kwargs)
#    4700 # Classic mode only:
#    4701 # ensure there are margins to allow for the
#    4702 # finite size of the symbols.  In v2.x, margins
#    4703 # are present by default, so we disable this
#    4704 # scatter-specific override.
#    4705 if mpl.rcParams['_internal.classic_mode']:
#
# File ~/anaconda3/envs/d8analysis/lib/python3.10/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~/anaconda3/envs/d8analysis/lib/python3.10/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: PathCollection.set() got an unexpected keyword argument 'vars'
