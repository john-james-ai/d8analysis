# %% [markdown]
# # Test QuantitativeOne

# %%
import pandas as pd
import warnings
from explorer.univariate import QuantitativeOne
from explorer.container import ExplorerContainer
from explorer.stats import DISTRIBUTIONS

# %%
container = ExplorerContainer()
container.init_resources()
container.wire(packages=["explorer"])

# %%
DATAFILE = "data/Credit Score Classification Dataset.csv"
NAME = 'Income'

# %% [markdown]
# ## QuantitativeOne

# %%
df = pd.read_csv(DATAFILE)
a = QuantitativeOne(data=df)

# %% [markdown]
# ## Describe

# %%
a.describe(name=NAME)

# %% [markdown]
# ## Distribution Test

# %%
print(a.test_distribution(name=NAME, approx=True))

# %% [markdown]
# ## Goodness of Fit Plots

# %%
a.gofplot(name=NAME, distribution="normal")

# %%
a.gofplot(name=NAME, distribution="chi2")

# %%
a.gofplot(name=NAME, distribution="exponential")

# %%
a.gofplot(name=NAME, distribution="gamma")

# %%
a.gofplot(name=NAME, distribution="logistic")

# %%
a.gofplot(name=NAME, distribution="uniform")

# %% [markdown]
# ## Cumulative Distribution Plots

# %%
a.cdfplot(name=NAME, distribution="normal")

# %%
a.cdfplot(name=NAME, distribution="chi2")

# %%
a.cdfplot(name=NAME, distribution="exponential")

# %%
a.cdfplot(name=NAME, distribution="gamma")

# %%
a.cdfplot(name=NAME, distribution="logistic")

# %%
a.cdfplot(name=NAME, distribution="uniform")

# %% [markdown]
# ## Empirical vs Theoretical Boxplots

# %%
a.boxplot(name=NAME, distribution="normal")

# %%
a.boxplot(name=NAME, distribution="chi2")

# %%
a.boxplot(name=NAME, distribution="exponential")

# %%
a.boxplot(name=NAME, distribution="gamma")

# %%
a.boxplot(name=NAME, distribution="logistic")

# %%
a.boxplot(name=NAME, distribution="uniform")

# %% [markdown]
# ## QQ Plots

# %%
a.qqplot(name=NAME, distribution="normal")

# %%
a.qqplot(name=NAME, distribution="exponential")

# %%
a.qqplot(name=NAME, distribution="gamma")

# %%
a.qqplot(name=NAME, distribution="logistic")

# %%
a.qqplot(name=NAME, distribution="uniform")
