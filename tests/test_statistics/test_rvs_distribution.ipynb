# %% [markdown]
# # RVS Distribution  Test

# %%
from d8analysis.stats.distribution import RVSDistribution
from d8analysis.container import d8analysisContainer
from d8analysis.service.io import IOService
import matplotlib  as mpl
print(mpl.__version__)
# Out:
# 3.7.1

# %%
container = d8analysisContainer()
container.init_resources()

# %%
FP = "data/Credit Score Classification Dataset.csv"

# %%
df = IOService.read(FP, index_col=None)

# %%
rvs = RVSDistribution()
rvs(data=df['Income'].values, distribution='uniform')
_ = rvs.histplot()
_ = rvs.histpdf()
_ = rvs.pdf()
_ = rvs.cdf()
_ = rvs.pdfcdf()
_ = rvs.ecdf()
