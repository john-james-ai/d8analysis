# %% [markdown]
# # Spearman Correlation Test

# %%
from explorer.stats.correlation.spearman import SpearmanCorrelationTest
from explorer.service.io import IOService
import numpy as np

# %%
FP = "data/Credit Score Classification Dataset.csv"

# %%
df = IOService.read(FP, index_col=None)
test = SpearmanCorrelationTest()
test(data=df[["Income","Age"]])
print(test.result)
test.result.plot()
# Out:
# 	                            test | Spearman's Correlation Test
# 	                      hypothesis | Correlation of Two Variables
# 	                              H0 | Distributions are uncorrelated
# 	                       statistic | Spearman correlation coefficient
# 	                           value | 0.6980383011470919
# 	                          pvalue | 2.8296708306045556e-25
# 	                       inference | The pvalue 0.0 is less than level of significance 5%; therefore, the null hypothesis is rejected. Correlation between Income and Age is significant.
# 	                           alpha | 0.05
# 	                          result | r(164)=0.7, p<.001 significant at 5%.
# 	                               x | Income
# 	                               y | Age
# <Axes: title={'center': "Spearman's Test for Correlation\nr(164)=0.7, p<.001 significant at 5%."}, xlabel='Income', ylabel='Age'>
