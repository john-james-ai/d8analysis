# %% [markdown]
# # Goodness of Fit Test
# ## Two Sample

# %%
from explorer.stats.goodness_of_fit.kstwo import KSTwoTest
from explorer.service.io import IOService
from scipy import stats

# %%
FP = "data/Credit Score Classification Dataset.csv"
STATISTICS = ['ks', 'ad', 'cvm']

# %%
df = IOService.read(FP, index_col=None)
female = df.loc[df['Gender'] == 'Female']['Income']
male = df.loc[df['Gender'] == 'Male']['Income']
female.name = 'female'
male.name = 'male'
female.head()
male.head()
# Out:
# 0     50000
# 2     75000
# 4    100000
# 6     40000
# 8     80000
# Name: female, dtype: int64
# 1    100000
# 3    125000
# 5    150000
# 7     60000
# 9    105000
# Name: male, dtype: int64

# %%
test = KSTwoTest()
test(sample1=female, sample2=male)
print(test.result)
test.result.plot()
test.result.plothist()
# Out:
# 	                            test | Kolmogorov-Smirnov Test
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Data drawn from the same distribution
# 	                       statistic | Kolmogorov–Smirnov
# 	                           value | 0.5014907573047108
# 	                          pvalue | 6.502925934610737e-10
# 	                       inference | The pvalue 0.0 is less than level of significance 0.05; therefore, the null hypothesis is rejected. The distributions are significantly different.
# 	                           alpha | 0.05
# 	                          result | (KS=0.5, p<0.05
# 	          reference_distribution | None
# <Axes: title={'center': 'Goodness of Fit\nDistributions of Female of Male\n(KS=0.5, p<0.05'}, xlabel='Value', ylabel='Probability Density'>
# <Axes: title={'center': 'Goodness of Fit\nDistributions of Female of Male'}, ylabel='Count'>

# %%
test = KSTwoTest()
test(sample1=female, sample2=female)
print(test.result)
test.result.plot()
test.result.plothist()
# Out:
# 	                            test | Kolmogorov-Smirnov Test
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Data drawn from the same distribution
# 	                       statistic | Kolmogorov–Smirnov
# 	                           value | 0.0
# 	                          pvalue | 1.0
# 	                       inference | The pvalue 1.0 is greater than level of significance 0.05; therefore, the null hypothesis is not rejected. The distributions are not significantly different.
# 	                           alpha | 0.05
# 	                          result | (KS=0.0, p>0.05
# 	          reference_distribution | None
# <Axes: title={'center': 'Goodness of Fit\nDistributions of Female of Female\n(KS=0.0, p>0.05'}, xlabel='Value', ylabel='Probability Density'>
# <Axes: title={'center': 'Goodness of Fit\nDistributions of Female of Female'}, ylabel='Count'>
