# %% [markdown]
# # ChiSquare Goodness of Fit Test

# %%
from d8analysis.stats.goodness_of_fit.chisquare import ChiSquareGOFTest
from d8analysis.service.io import IOService
import numpy as np

# %%
FP = "data/Credit Score Classification Dataset.csv"

# %%
df = IOService.read(FP, index_col=None)
test = ChiSquareGOFTest()
test(data=df["Education"])
print(test.result)
test.result.plot()
# Out:
# 	                            test | Chi-Square Test of Goodness of Fit
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Categorical data have the given frequencies
# 	                       statistic | X²
# 	                           value | 5.085365853658536
# 	                          pvalue | 0.27865004658054116
# 	                       inference | The pvalue 0.28 is greater than level of significance 5%; therefore, the null hypothesis is not rejected. The evidence against a common distribution was not significant.
# 	                           alpha | 0.05
# 	                          result | X²(4, N=164)=5.09, P=0.279 significant at 5%.
# 	                  interpretation | None
# 	                             dof | 4
# <Axes: title={'center': 'X² Goodness of Fit\nTest Result\nX²(4, N=164)=5.09, P=0.279 significant at 5%.'}, xlabel='$X^2$', ylabel='Probability Density'>
