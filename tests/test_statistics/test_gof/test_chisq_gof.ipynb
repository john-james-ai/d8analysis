# %% [markdown]
# # ChiSquare Goodness of Fit Test

# %%
from explorer.stats.goodness_of_fit.chisquare import ChiSquareGOFTest
from explorer.service.io import IOService
import numpy as np

# %%
FP = "data/Credit Score Classification Dataset.csv"

# %%
df = IOService.read(FP, index_col=None)
test = ChiSquareGOFTest()
test(data=df["Credit Rating"])
print(test.result)
test.result.plot()
# Out:
# 	                            test | Chi-Square Test of Goodness of Fit
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Categorical data have the given frequencies
# 	                       statistic | X²
# 	                           value | 97.40243902439025
# 	                          pvalue | 7.068529972969942e-22
# 	                       inference | The pvalue 0.0 is less than level of significance 5%; therefore, the null hypothesis is rejected. The data do not have the expected frequencies.
# 	                           alpha | 0.05
# 	                          result | X²(2, N=164)=97.4, p<.001 significant at 5%.
# 	                             dof | 2
# <Axes: title={'center': 'X² Goodness of Fit\nTest Result\nX²(2, N=164)=97.4, p<.001 significant at 5%.'}, xlabel='$X^2$', ylabel='Probability Density'>
