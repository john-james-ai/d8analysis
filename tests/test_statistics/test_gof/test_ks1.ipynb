# %% [markdown]
# # Goodness of Fit Test

# %%
from explorer.stats.goodness_of_fit.ksone import KSOneTest
from explorer.service.io import IOService
from scipy import stats
import numpy as np
from explorer.stats.distribution import DISTRIBUTIONS

# %%
FP = "data/Credit Score Classification Dataset.csv"
STATISTICS = ['ks', 'ad', 'cvm']

# %%
df = IOService.read(FP, index_col=None)

test = KSOneTest()
test(data=df["Income"], reference_distribution='normal')
print(test.result)
test.result.plot()
test.result.plotpdf()
test.result.plotcdf()
# Out:
# 	                            test | Kolmogorov-Smirnov Test
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Data drawn from the reference distribution
# 	                       statistic | Kolmogorov–Smirnov
# 	                           value | 0.05836925224122724
# 	                          pvalue | 0.18811881188118812
# 	                       inference | The pvalue 0.19 is greater than level of significance 0.05; therefore, the null hypothesis is not rejected. The data were drawn from the reference distribution.
# 	                           alpha | 0.05
# 	                          result | (N=164)=0.06, p>0.05
# 	          reference_distribution | normal
# <Axes: title={'center': 'Goodness of Fit\nNormal Distribution\n(N=164)=0.06, p>0.05'}, xlabel='Value', ylabel='Probability Density'>
# ...

# %%
test(data=df["Income"], reference_distribution='beta')
print(test.result)
test.result.plot()
test.result.plotpdf()
test.result.plotcdf()
# Out:
# /home/john/anaconda3/envs/explorer/lib/python3.10/site-packages/scipy/stats/_continuous_distns.py:709: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# 	                            test | Kolmogorov-Smirnov Test
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Data drawn from the reference distribution
# 	                       statistic | Kolmogorov–Smirnov
# 	                           value | 0.0481965660695749
# 	                          pvalue | 0.46534653465346537
# 	                       inference | The pvalue 0.47 is greater than level of significance 0.05; therefore, the null hypothesis is not rejected. The data were drawn from the reference distribution.
# 	                           alpha | 0.05
# 	                          result | (N=164)=0.05, p>0.05
# 	          reference_distribution | beta
# ...

# %%
test(data=df["Income"], reference_distribution='gamma')
print(test.result)
test.result.plot()

test.result.plotpdf()
test.result.plotcdf()
# Out:
# 	                            test | Kolmogorov-Smirnov Test
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Data drawn from the reference distribution
# 	                       statistic | Kolmogorov–Smirnov
# 	                           value | 0.05503663820895821
# 	                          pvalue | 0.12871287128712872
# 	                       inference | The pvalue 0.13 is greater than level of significance 0.05; therefore, the null hypothesis is not rejected. The data were drawn from the reference distribution.
# 	                           alpha | 0.05
# 	                          result | (N=164)=0.06, p>0.05
# 	          reference_distribution | gamma
# <Axes: title={'center': 'Goodness of Fit\nGamma Distribution\n(N=164)=0.06, p>0.05'}, xlabel='Value', ylabel='Probability Density'>
# ...

# %%
test(data=df["Income"], reference_distribution='f')
print(test.result)
test.result.plot()

test.result.plotpdf()
test.result.plotcdf()
# Out:
# /home/john/anaconda3/envs/explorer/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2789: RuntimeWarning: invalid value encountered in scalar multiply
#   Lhat = muhat - Shat*mu
# 	                            test | Kolmogorov-Smirnov Test
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Data drawn from the reference distribution
# 	                       statistic | Kolmogorov–Smirnov
# 	                           value | 0.1086575932197712
# 	                          pvalue | 0.009900990099009901
# 	                       inference | The pvalue 0.01 is less than level of significance 0.05; therefore, the null hypothesis is rejected. The data were not drawn from the reference distribution.
# 	                           alpha | 0.05
# 	                          result | (N=164)=0.11, p<0.05
# 	          reference_distribution | f
# ...

# %%
test(data=df["Income"], reference_distribution='logistic')
print(test.result)
test.result.plot()

test.result.plotpdf()
test.result.plotcdf()
# Out:
# 	                            test | Kolmogorov-Smirnov Test
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Data drawn from the reference distribution
# 	                       statistic | Kolmogorov–Smirnov
# 	                           value | 0.05595089558374089
# 	                          pvalue | 0.1188118811881188
# 	                       inference | The pvalue 0.12 is greater than level of significance 0.05; therefore, the null hypothesis is not rejected. The data were drawn from the reference distribution.
# 	                           alpha | 0.05
# 	                          result | (N=164)=0.06, p>0.05
# 	          reference_distribution | logistic
# <Axes: title={'center': 'Goodness of Fit\nLogistic Distribution\n(N=164)=0.06, p>0.05'}, xlabel='Value', ylabel='Probability Density'>
# ...

# %%
test(data=df["Income"], reference_distribution='lognorm')
print(test.result)
test.result.plot()

test.result.plotpdf()
test.result.plotcdf()
# Out:
# 	                            test | Kolmogorov-Smirnov Test
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Data drawn from the reference distribution
# 	                       statistic | Kolmogorov–Smirnov
# 	                           value | 0.7415925398532963
# 	                          pvalue | 0.07920792079207921
# 	                       inference | The pvalue 0.08 is greater than level of significance 0.05; therefore, the null hypothesis is not rejected. The data were drawn from the reference distribution.
# 	                           alpha | 0.05
# 	                          result | (N=164)=0.74, p>0.05
# 	          reference_distribution | lognorm
# <Axes: title={'center': 'Goodness of Fit\nLognorm Distribution\n(N=164)=0.74, p>0.05'}, xlabel='Value', ylabel='Probability Density'>
# ...

# %%
test(data=df["Income"], reference_distribution='weibull')
print(test.result)
test.result.plot()

test.result.plotpdf()
test.result.plotcdf()
# Out:
# 	                            test | Kolmogorov-Smirnov Test
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Data drawn from the reference distribution
# 	                       statistic | Kolmogorov–Smirnov
# 	                           value | 0.05082552183583244
# 	                          pvalue | 0.26732673267326734
# 	                       inference | The pvalue 0.27 is greater than level of significance 0.05; therefore, the null hypothesis is not rejected. The data were drawn from the reference distribution.
# 	                           alpha | 0.05
# 	                          result | (N=164)=0.05, p>0.05
# 	          reference_distribution | weibull
# <Axes: title={'center': 'Goodness of Fit\nWeibull Distribution\n(N=164)=0.05, p>0.05'}, xlabel='Value', ylabel='Probability Density'>
# ...

# %%
test(data=df["Income"], reference_distribution='uniform')
print(test.result)
test.result.plot()

test.result.plotpdf()
test.result.plotcdf()
# Out:
# 	                            test | Kolmogorov-Smirnov Test
# 	                      hypothesis | Goodness of Fit
# 	                              H0 | Data drawn from the reference distribution
# 	                       statistic | Kolmogorov–Smirnov
# 	                           value | 0.1864745011086475
# 	                          pvalue | 0.009900990099009901
# 	                       inference | The pvalue 0.01 is less than level of significance 0.05; therefore, the null hypothesis is rejected. The data were not drawn from the reference distribution.
# 	                           alpha | 0.05
# 	                          result | (N=164)=0.19, p<0.05
# 	          reference_distribution | uniform
# <Axes: title={'center': 'Goodness of Fit\nUniform Distribution\n(N=164)=0.19, p<0.05'}, xlabel='Value', ylabel='Probability Density'>
# ...
