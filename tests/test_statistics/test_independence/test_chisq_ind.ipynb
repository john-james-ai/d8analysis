# %% [markdown]
# # ChiSquare Independence

# %%
from explorer.stats.independence.chisquare import ChiSquareIndependenceTest
from explorer.service.io import IOService
import numpy as np

# %%
FP = "data/Credit Score Classification Dataset.csv"

# %%
df = IOService.read(FP, index_col=None)
test = ChiSquareIndependenceTest()
test(data=df[["Marital Status", "Education"]])
print(test.result)
_ = test.result.plot()
_ = test.result.plot_obs_exp()
# Out:
# 	                            test | Chi-Square of Independence
# 	                      hypothesis | Independence of Two Variables
# 	                              H0 | Two or more categorical variables are independent
# 	                       statistic | X²
# 	                           value | 27.34341791007928
# 	                          pvalue | 1.69407621859777e-05
# 	                       inference | The pvalue 0.0 is less than level of significance 0.05; therefore, the null hypothesis is rejected. The relationship between the variables is significant.
# 	                           alpha | 0.05
# 	                          result | X²(4, N=164)=27.34, p<.001 significant at 5%.
# 	                             dof | 4
# 	                               x | Marital Status
# 	                               y | Education
#
#              Education  Married  Single   Dataset
# 0   Associate's Degree     5.00   20.00  Observed
# 1    Bachelor's Degree    27.00   15.00  Observed
# ...

# %%
print('0x1D40F')
# Out:
# 0x1D40F
